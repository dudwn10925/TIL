# %% [markdown]
# ### <strong>Anaconda</strong>
#
# \> conda install pandas # 데이터 분석 모듈인 pandas 설치
#
# \> conda create -n basic python=3.8 # basic이라는 가상환경 생성
#
# \> conda activate basic
#
# \> conda env remove -n basic

# %% [markdown]
# ## <strong>Python

# %% [markdown]
# 0103

# %%
a = 0xabc    # 16진수 hexa decimal (%x)
b = 0o24    # 8진수 octal (%o)
print(a, b)
print(a / b)  # print(): 문자열로 표현
print(a // b)
# Out:
# 2748 20
# 137.4
# 137

# %%
str = "it's mine"
str
# Out:
# "it's mine"

# %%
# \는 다음에 오는 문자를 인식하라는 것
str1 = 'it\'s mine'
print(str1)

str2 = '"Python is very easy."\
 he says'
print(str2)

multiline = """
Life is to short
You need python
"""
print(multiline)    # ''' '''도 가능, 개행을 포함한 문자열 표현
# Out:
# it's mine
# "Python is very easy." he says
#
# Life is to short
# You need python

# %%
head = 'Python'
tail = " is fun"
print(head + tail)
print("=" * 18)
print(head * 2)
print(len(tail))
print(tail[-3])
print(tail[3:-1])
# Out:
# Python is fun
# ...
# PythonPython
# 7
# f
#  fu

# %%
word = 'pithon'   # 인덱싱으로 변경 불가
word[0:1] + 'y' + word[2:]
# Out:
# 'python'

# %%
'I ate %d apples. so I was sick for %s days.' %(100, 'seven')
"Hi I'm %sju" %0
'Error is %d%%' %98
# Out:
# 'Error is 98%'

# %%
print("%-10sjane" %"hi")
print('%10.4f' %3.141592)
# %c: 문자 1개, character
# Out:
# hi        jane
#     3.1416

# %% [markdown]
# 0104

# %%
print("I ate {0} apples. so I was sick for {day} days".format(100, day='seven'))
print("{0:*>7}".format('hi'))
print("{0:10.4f}".format(3.141592))
print("%10.4f" %3.141592)
# Out:
# I ate 100 apples. so I was sick for seven days
# *****hi
#     3.1416
#     3.1416

# %%
# f-formating
print(f"{'hi':$^10}")

# dictionary
d = {"name": '홍길동', 'age': 30}   # key - value
f"나의 이름은 {d['name']}입니다.\
 나이는 {d['age']}입니다."

print('{0}{1}{0}'.format('abra', 'cad'))
coord = {"latitude": '37.24N', 'longitude': "-115.81W"}
print('Coordinates: {latitude}, {longitude}'.format(**coord))    # **: 두 번 분해
f"Coordinates: {coord['latitude']}, {coord['longitude']}"
# Out:
# $$$$hi$$$$
# abracadabra
# Coordinates: 37.24N, -115.81W
# 'Coordinates: 37.24N, -115.81W'

# %%
# 문자열 함수
str = "Life is too short"
print(str.count('o'))
print(str.find('f'))    # 없는 문자로 find()하면 -1
print(str.index('f'))   # 없는 문자로 index()하면 error
print(', '.join('abcd'))
print(', '.join(['a', 'b', 'c', 'd']))

print(str.upper(), str.lower())
a = '  hi  '
print(a.lstrip())
print(a.rstrip())
print(a.strip())

print(str.replace('Life', 'Your leg'))    # 실질적으로 str이 변하는 것이 아님
a = 'a:b:c:d'
print(a.split(":"))
# Out:
# 3
# 2
# 2
# a, b, c, d
# a, b, c, d
# LIFE IS TOO SHORT life is too short
# hi
#   hi
# hi
# Your leg is too short
# ['a', 'b', 'c', 'd']

# %%
# 리스트
list = [1, 2, ['a', 'b', ['Life', 'is', 'good']]]
list[2][2][1]
# Out:
# 'is'
